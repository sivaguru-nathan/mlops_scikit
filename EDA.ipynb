# %%
import pandas as pd

# %%
df=pd.read_csv("challenge.csv")#reading the csv

# %%
df=df.iloc[:,1:]# deleting the id

# %%
df.describe()
# Out:
#             target          l1          l2          l3          l4          l5
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
# Find any null value
df.isnull().sum()
# Out:
# type      0
# target    0
# l1        0
# l2        0
# l3        0
# l4        0
# l5        0
# dtype: int64

# %%
#check on duplicates
df.duplicated().any()
# Out:
# False

# %%
# pair plot 
import seaborn as sns
import matplotlib.pyplot as plt
 
 
sns.pairplot(df, height=2)

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
 
 
sns.heatmap(df.corr(method='pearson'),
            annot = True);
 
plt.show()
# Out:
# /tmp/ipykernel_192/58412161.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method='pearson'),

# %% [markdown]
# ### Observation
# from the correlation matrix its clearly seen that the target variable is correlated to all the variables. l1,l2,l3,l5 are correlated above 80. since l1 l2 l3 are correlateed to each other we can take any one of the variables. from the scatter plot we can see that l3 and l5 has a good curve fit. we will get low MSE if we do regression with these variables or with one of these variables
